# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import geopandas as gpd
import geoplot as gplt
import geoplot.crs as gcrs
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import matplotlib as mpl

gd_src = './node_modules/preprocessing/preprocessing/geodata/maps/dist/{}/{}-c005-s010-vw-pr.geojson'
onemil_src = './node_modules/preprocessing/data/1Mdataset.csv'
nc_src = './datasets/output.csv'

# %%
def load_gd(level='dis'):
    return gpd.read_file(
        gd_src.format(level, level)
    )

# %%
def disp_gd(level):
    gd = load_gd(level)
    gd.info()
    print(gd.head())
    gplt.polyplot(
        gd, 
        projection=gcrs.AlbersEqualArea(), 
        edgecolor='blue', 
        linewidth=0.05,
        figsize=(10,10)
    )

# %%
def disp_all_levels():
    for level in ['div', 'dis', 'upa', 'uni', 'mou']:
        disp_gd(level)
        
disp_all_levels()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   area      8 non-null      float64
#  1   div       8 non-null      object
#  2   geometry  8 non-null      geometry
# dtypes: float64(1), geometry(1), object(1)
# memory usage: 320.0+ bytes
#            area         div                                           geometry
# 0  1.054456e+10  Mymensingh  MULTIPOLYGON (((89.78907 24.57229, 89.78899 24...
# 1  2.074963e+10      Khulna  MULTIPOLYGON (((89.24623 21.68914, 89.25006 21...
# 2  1.237275e+10      Sylhet  MULTIPOLYGON (((91.81038 24.21725, 91.80751 24...
# 3  1.822871e+10    Rajshahi  MULTIPOLYGON (((89.35535 23.88594, 89.35434 23...
# 4  1.628660e+10     Rangpur  MULTIPOLYGON (((89.70255 26.17716, 89.69971 26...
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 4 columns):
# ...
